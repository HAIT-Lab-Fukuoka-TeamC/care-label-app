# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
img = cv2.imread('../images/whites/no-white.png')

# %%
plt.imshow(img)

# %%
# ガンマ値を指定
gamma = 11

# 色対応表を定義
look_up_table = np.zeros((256, 1), dtype='uint8')
# すべての対応表を事前に計算しておく
for i in range(256):
    look_up_table[i][0] = 255 * pow(float(i) / 255, 1.0 / gamma)
img_gamma = cv2.LUT(img, look_up_table)
plt.imshow(img_gamma)

# %%
save_img = cv2.cvtColor(img_gamma, cv2.COLOR_RGB2BGR)
cv2.imwrite(f'../images/whites/usui{str(gamma)}.png', save_img)
# Out:
# True

# %%
# Out:
# True
