# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

def addSaltPepperNoise(src,amount):
    row,col,ch = src.shape
    s_vs_p = 0.5
    out = src.copy()
    # Salt mode
    num_salt = np.ceil(amount * src.size * s_vs_p)
    coords = [np.random.randint(0, i-1 , int(num_salt))
                 for i in src.shape]
    out[coords[:-1]] = (255,255,255)

    # Pepper mode
    num_pepper = np.ceil(amount* src.size * (1. - s_vs_p))
    coords = [np.random.randint(0, i-1 , int(num_pepper))
             for i in src.shape]
    out[coords[:-1]] = (0,0,0)
    return out

def padding_images(dir_name, file_name, head):
    img = cv2.imread(file_name)
    save_path = './pre-all/train/' + dir_name + '/' + str(head) + '_'
    usui = 3

    for index in range(1, usui):
        # ガンマ値を指定
        gamma = index

        # 色対応表を定義
        look_up_table = np.zeros((256, 1), dtype='uint8')
        # すべての対応表を事前に計算しておく
        for i in range(256):
            look_up_table[i][0] = 255 * pow(float(i) / 255, 1.0 / gamma)
        img_gamma = cv2.LUT(img, look_up_table)
        img = cv2.cvtColor(img_gamma, cv2.COLOR_RGB2BGR)
        cv2.imwrite(f'{save_path}usui_{str(gamma)}.png', img)
        for i in range(20):
            amount = i * 0.002
            noise_salt = addSaltPepperNoise(img, amount)
            save_img = cv2.cvtColor(noise_salt, cv2.COLOR_RGB2BGR)
            cv2.imwrite(f'{save_path}usui_{str(gamma)}_noise{str(i)}.png', save_img)

            # 表示する画像のサイズ(変換前と同じサイズに指定)
        size = (img.shape[0], img.shape[1])
        # 回転の中心位置を表す座標（画像の中心に指定）
        center = (int(size[0]/2), int(size[1]/2))


        # 拡大･縮小の比率
        scale = 1.0

        for i in range(1, 30):
            # 回転角度
            angle = i

            # 回転変換を表す行列をつくる
            # (中心位置, 回転角度, 拡大･縮小の比率)
            rotation_matrix = cv2.getRotationMatrix2D(center, angle, scale)
            # 回転変換を行う
            # (画像, 回転行列, 変換後の画像サイズ)
            rotated = cv2.warpAffine(img, rotation_matrix, size,borderValue=(255, 255, 255))

            save_img = cv2.cvtColor(rotated, cv2.COLOR_RGB2BGR)
            cv2.imwrite(f'{save_path}usui_{str(gamma)}_rotate_{str(angle)}.png', save_img)

            for j in range(6):
                amount = j * 0.002
                noise_salt = addSaltPepperNoise(save_img, amount)
                save_img = cv2.cvtColor(noise_salt, cv2.COLOR_RGB2BGR)
                cv2.imwrite(f'{save_path}usui_{str(gamma)}_rotate_{str(angle)}_noise{str(j)}.png', save_img)

        for i in range(330, 360):
            # 回転角度
            angle = i

            # 回転変換を表す行列をつくる
            # (中心位置, 回転角度, 拡大･縮小の比率)
            rotation_matrix = cv2.getRotationMatrix2D(center, angle, scale)
            # 回転変換を行う
            # (画像, 回転行列, 変換後の画像サイズ)
            rotated = cv2.warpAffine(img, rotation_matrix, size,borderValue=(255, 255, 255))

            save_img = cv2.cvtColor(rotated, cv2.COLOR_RGB2BGR)
            cv2.imwrite(f'{save_path}usui_{str(gamma)}_rotate_{str(angle)}.png', save_img)

            for j in range(6):
                amount = j * 0.002
                noise_salt = addSaltPepperNoise(save_img, amount)
                save_img = cv2.cvtColor(noise_salt, cv2.COLOR_RGB2BGR)
                cv2.imwrite(f'{save_path}usui_{str(gamma)}_rotate_{str(angle)}_noise{str(j)}.png', save_img)

            # 変換後の画像のサイズを指定
        rows, cols, channnels = img.shape
        move = 6
        for i in range(1, move):
            # 変換行列
            M = np.float32([[1,0,i],[0,1,0]])
            # 並進移動の実行
            moved = cv2.warpAffine(img, M, (cols, rows),borderValue=(255, 255, 255))


            save_img = cv2.cvtColor(moved, cv2.COLOR_RGB2BGR)
            cv2.imwrite(f'{save_path}usui_{str(gamma)}_right_{str(i)}.png', save_img)

            for j in range(6):
                amount = j * 0.002
                noise_salt = addSaltPepperNoise(save_img, amount)
                save_img = cv2.cvtColor(noise_salt, cv2.COLOR_RGB2BGR)
                cv2.imwrite(f'{save_path}usui_{str(gamma)}_right_{str(i)}_noise{str(j)}.png', save_img)

        for i in range(1, move):
            # 変換行列
            M = np.float32([[1,0,-i],[0,1,0]])
            # 並進移動の実行
            moved = cv2.warpAffine(img, M, (cols, rows),borderValue=(255, 255, 255))


            save_img = cv2.cvtColor(moved, cv2.COLOR_RGB2BGR)
            cv2.imwrite(f'{save_path}usui_{str(gamma)}_left_{str(i)}.png', save_img)



            for j in range(6):
                amount = j * 0.002
                noise_salt = addSaltPepperNoise(save_img, amount)
                save_img = cv2.cvtColor(noise_salt, cv2.COLOR_RGB2BGR)
                cv2.imwrite(f'{save_path}usui_{str(gamma)}_left_{str(i)}_noise{str(j)}.png', save_img)


        for i in range(1, move):
            # 変換行列
            M = np.float32([[1,0,0],[0,1,i]])
            # 並進移動の実行
            moved = cv2.warpAffine(img, M, (cols, rows),borderValue=(255, 255, 255))


            save_img = cv2.cvtColor(moved, cv2.COLOR_RGB2BGR)
            cv2.imwrite(f'{save_path}usui_{str(gamma)}_down_{str(i)}.png', save_img)


            for j in range(6):
                amount = j * 0.002
                noise_salt = addSaltPepperNoise(save_img, amount)
                save_img = cv2.cvtColor(noise_salt, cv2.COLOR_RGB2BGR)
                cv2.imwrite(f'{save_path}usui_{str(gamma)}_down_{str(i)}_noise{str(j)}.png', save_img)

        for i in range(1, move):
            # 変換行列
            M = np.float32([[1,0,0],[0,1,-i]])
            # 並進移動の実行
            moved = cv2.warpAffine(img, M, (cols, rows),borderValue=(255, 255, 255))


            save_img = cv2.cvtColor(moved, cv2.COLOR_RGB2BGR)
            cv2.imwrite(f'{save_path}usui_{str(gamma)}_up_{str(i)}.png', save_img)


            for j in range(6):
                amount = j * 0.002
                noise_salt = addSaltPepperNoise(save_img, amount)
                save_img = cv2.cvtColor(noise_salt, cv2.COLOR_RGB2BGR)
                cv2.imwrite(f'{save_path}usui_{str(gamma)}_up_{str(i)}_noise{str(j)}.png', save_img)

        for i in range(1, move):
            # 変換行列
            M = np.float32([[1,0,-i],[0,1,-i]])
            # 並進移動の実行
            moved = cv2.warpAffine(img, M, (cols, rows),borderValue=(255, 255, 255))


            save_img = cv2.cvtColor(moved, cv2.COLOR_RGB2BGR)
            cv2.imwrite(f'{save_path}usui_{str(gamma)}_leftup_{str(i)}.png', save_img)


            for j in range(6):
                amount = j * 0.002
                noise_salt = addSaltPepperNoise(save_img, amount)
                save_img = cv2.cvtColor(noise_salt, cv2.COLOR_RGB2BGR)
                cv2.imwrite(f'{save_path}usui_{str(gamma)}_leftup_{str(i)}_noise{str(j)}.png', save_img)

        for i in range(1, move):
            # 変換行列
            M = np.float32([[1,0,i],[0,1,-i]])
            # 並進移動の実行
            moved = cv2.warpAffine(img, M, (cols, rows),borderValue=(255, 255, 255))


            save_img = cv2.cvtColor(moved, cv2.COLOR_RGB2BGR)
            cv2.imwrite(f'{save_path}usui_{str(gamma)}_rightup_{str(i)}.png', save_img)

            for j in range(6):
                amount = j * 0.002
                noise_salt = addSaltPepperNoise(save_img, amount)
                save_img = cv2.cvtColor(noise_salt, cv2.COLOR_RGB2BGR)
                cv2.imwrite(f'{save_path}usui_{str(gamma)}_rightup_{str(i)}_noise{str(j)}.png', save_img)

        for i in range(1, move):
            # 変換行列
            M = np.float32([[1,0,i],[0,1,i]])
            # 並進移動の実行
            moved = cv2.warpAffine(img, M, (cols, rows),borderValue=(255, 255, 255))


            save_img = cv2.cvtColor(moved, cv2.COLOR_RGB2BGR)
            cv2.imwrite(f'{save_path}usui_{str(gamma)}_rightdown_{str(i)}.png', save_img)

            for j in range(6):
                amount = j * 0.002
                noise_salt = addSaltPepperNoise(save_img, amount)
                save_img = cv2.cvtColor(noise_salt, cv2.COLOR_RGB2BGR)
                cv2.imwrite(f'{save_path}usui_{str(gamma)}_rightdown_{str(i)}_noise{str(j)}.png', save_img)

        for i in range(1, move):
            # 変換行列
            M = np.float32([[1,0,-i],[0,1,i]])
            # 並進移動の実行
            moved = cv2.warpAffine(img, M, (cols, rows),borderValue=(255, 255, 255))


            save_img = cv2.cvtColor(moved, cv2.COLOR_RGB2BGR)
            cv2.imwrite(f'{save_path}usui_{str(gamma)}_leftdown_{str(i)}.png', save_img)

            for j in range(6):
                amount = j * 0.002
                noise_salt = addSaltPepperNoise(save_img, amount)
                save_img = cv2.cvtColor(noise_salt, cv2.COLOR_RGB2BGR)
                cv2.imwrite(f'{save_path}usui_{str(gamma)}_leftdown_{str(i)}_noise{str(j)}.png', save_img)

# %%
import glob
files = glob.glob("./pre-all/train-seeds/**", recursive=True)
files
# Out:
# ['./pre-all/train-seeds/',
#  './pre-all/train-seeds/ironing_upto150',
#  './pre-all/train-seeds/ironing_upto150/IMG_20190911_212318.jpg',
#  './pre-all/train-seeds/ironing_upto150/2.jpg',
#  './pre-all/train-seeds/ironing_upto150/IMG_20190911_212149.jpg',
#  './pre-all/train-seeds/ironing_upto150/ironing_upto150_2.jpg',
#  './pre-all/train-seeds/ironing_upto150/1.png',
#  './pre-all/train-seeds/ironing_upto150/ironing_upto150_3.jpg',
#  './pre-all/train-seeds/ironing_upto150/ironing_upto150_1.jpg',
#  './pre-all/train-seeds/ironing_upto150/3.jpeg',
#  './pre-all/train-seeds/bleachable_oxygen',
#  './pre-all/train-seeds/bleachable_oxygen/1.jpeg',
#  './pre-all/train-seeds/bleachable_oxygen/IMG_20190910_235440.jpg',
#  './pre-all/train-seeds/40_weak',
#  './pre-all/train-seeds/40_weak/4.jpeg',
#  './pre-all/train-seeds/40_weak/2.jpg',
#  './pre-all/train-seeds/40_weak/IMG_20190910_235118.jpg',
#  './pre-all/train-seeds/40_weak/3.jpg',
#  './pre-all/train-seeds/40_weak/40_weak_2.jpg',
#  './pre-all/train-seeds/40_weak/40_weak_1.jpg',
#  './pre-all/train-seeds/40_weak/1.png',
#  './pre-all/train-seeds/40_weak/40_weak_3.jpg',
#  './pre-all/train-seeds/40_weak/IMG_20190911_212228.jpg',
#  './pre-all/train-seeds/wetcleaning_ok',
#  './pre-all/train-seeds/wetcleaning_ok/1.jpg',
#  './pre-all/train-seeds/60_weak',
#  './pre-all/train-seeds/60_weak/1.png',
#  './pre-all/train-seeds/30_weak',
#  './pre-all/train-seeds/30_weak/2.png',
#  './pre-all/train-seeds/30_weak/1.jpg',
#  './pre-all/train-seeds/flat_dry_wet',
#  './pre-all/train-seeds/flat_dry_wet/1.jpg',
#  './pre-all/train-seeds/30',
#  './pre-all/train-seeds/30/2.jpg',
#  './pre-all/train-seeds/30/4.png',
#  './pre-all/train-seeds/30/1.jpg',
#  './pre-all/train-seeds/30/3.png',
#  './pre-all/train-seeds/50_weak',
#  './pre-all/train-seeds/50_weak/1.png',
#  './pre-all/train-seeds/60',
#  './pre-all/train-seeds/60/1.png',
#  './pre-all/train-seeds/drycleaning_F',
#  './pre-all/train-seeds/drycleaning_F/1.jpg',
#  './pre-all/train-seeds/hanging_dry_wetshade',
#  './pre-all/train-seeds/hanging_dry_wetshade/1.jpg',
#  './pre-all/train-seeds/donot_drycleaning',
#  './pre-all/train-seeds/donot_drycleaning/IMG_20190910_235237.jpg',
#  './pre-all/train-seeds/donot_drycleaning/IMG_20190909_234517.jpg',
#  './pre-all/train-seeds/donot_drycleaning/IMG_20190911_212159.jpg',
#  './pre-all/train-seeds/donot_drycleaning/IMG_20190911_212029.jpg',
#  './pre-all/train-seeds/donot_drycleaning/IMG_20190909_234107.jpg',
#  './pre-all/train-seeds/donot_drycleaning/IMG_0921.jpeg',
#  './pre-all/train-seeds/donot_drycleaning/IMG_20190910_235543.jpg',
#  './pre-all/train-seeds/donot_drycleaning/IMG_20190910_235411.jpg',
#  './pre-all/train-seeds/flat_dry_wetshade',
#  './pre-all/train-seeds/flat_dry_wetshade/1.jpg',
#  './pre-all/train-seeds/bleachable',
#  './pre-all/train-seeds/bleachable/jisl0001-ichiran.jpg',
#  './pre-all/train-seeds/donot_ironing',
#  './pre-all/train-seeds/donot_ironing/jisl0001-ichiran (1).jpg',
#  './pre-all/train-seeds/drycleaning_P_weak',
#  './pre-all/train-seeds/drycleaning_P_weak/IMG_20190911_011303.jpg',
#  './pre-all/train-seeds/drycleaning_P_weak/IMG_0917.jpeg',
#  './pre-all/train-seeds/40',
#  './pre-all/train-seeds/40/card_42748_001.jpg',
#  './pre-all/train-seeds/not_bleachable',
#  './pre-all/train-seeds/not_bleachable/IMG_20190911_212350.jpg',
#  './pre-all/train-seeds/not_bleachable/not_bleachable_1.jpg',
#  './pre-all/train-seeds/not_bleachable/IMG_20190911_211815.jpg',
#  './pre-all/train-seeds/not_bleachable/3.jpg',
#  './pre-all/train-seeds/not_bleachable/1.png',
#  './pre-all/train-seeds/not_bleachable/IMG_20190911_212112.jpg',
#  './pre-all/train-seeds/not_bleachable/4.jpg',
#  './pre-all/train-seeds/not_bleachable/IMG_20190911_211938.jpg',
#  './pre-all/train-seeds/not_bleachable/IMG_20190910_235141.jpg',
#  './pre-all/train-seeds/not_bleachable/not_bleachable_2.jpg',
#  './pre-all/train-seeds/not_bleachable/2.jpeg',
#  './pre-all/train-seeds/not_bleachable/IMG_20190911_212244.jpg',
#  './pre-all/train-seeds/hanging_dry',
#  './pre-all/train-seeds/hanging_dry/1.jpg',
#  './pre-all/train-seeds/70',
#  './pre-all/train-seeds/70/1.png',
#  './pre-all/train-seeds/weetcleaning_very_weak',
#  './pre-all/train-seeds/weetcleaning_very_weak/IMG_20190911_211913.jpg',
#  './pre-all/train-seeds/weetcleaning_very_weak/1.jpg',
#  './pre-all/train-seeds/weetcleaning_very_weak/IMG_20190911_212439.jpg',
#  './pre-all/train-seeds/weetcleaning_very_weak/IMG_20190911_212212.jpg',
#  './pre-all/train-seeds/40_very_weak',
#  './pre-all/train-seeds/40_very_weak/1.jpg',
#  './pre-all/train-seeds/tumble_dry_upto60',
#  './pre-all/train-seeds/tumble_dry_upto60/IMG_0923.jpeg',
#  './pre-all/train-seeds/flat_dry',
#  './pre-all/train-seeds/flat_dry/1.jpg',
#  './pre-all/train-seeds/drycleaning_P',
#  './pre-all/train-seeds/drycleaning_P/1.jpg',
#  './pre-all/train-seeds/50',
#  './pre-all/train-seeds/50/1.png',
#  './pre-all/train-seeds/ironing_upto200',
#  './pre-all/train-seeds/ironing_upto200/20160710_1748544.jpg',
#  './pre-all/train-seeds/hand-wash',
#  './pre-all/train-seeds/hand-wash/IMG_20190911_212341.jpg',
#  './pre-all/train-seeds/hand-wash/1.jpeg',
#  './pre-all/train-seeds/hand-wash/IMG_20190911_211805.jpg',
#  './pre-all/train-seeds/hanging_dry_wet',
#  './pre-all/train-seeds/hanging_dry_wet/1.jpg',
#  './pre-all/train-seeds/donot_tumble_dry',
#  './pre-all/train-seeds/donot_tumble_dry/IMG_20190911_211948.jpg',
#  './pre-all/train-seeds/donot_tumble_dry/IMG_20190911_211825.jpg',
#  './pre-all/train-seeds/donot_tumble_dry/IMG_20190911_212123.jpg',
#  './pre-all/train-seeds/donot_tumble_dry/3.jpg',
#  './pre-all/train-seeds/donot_tumble_dry/donot_tumble_dry_1.jpg',
#  './pre-all/train-seeds/donot_tumble_dry/1.png',
#  './pre-all/train-seeds/donot_tumble_dry/IMG_20190910_235155.jpg',
#  './pre-all/train-seeds/donot_tumble_dry/donot_tumble_dry_2.jpg',
#  './pre-all/train-seeds/donot_tumble_dry/donot_tumble_dry_3.jpg',
#  './pre-all/train-seeds/donot_tumble_dry/IMG_20190911_212403.jpg',
#  './pre-all/train-seeds/donot_tumble_dry/2.jpeg',
#  './pre-all/train-seeds/donot_tumble_dry/IMG_20190911_212256.jpg',
#  './pre-all/train-seeds/flat_dry_shade',
#  './pre-all/train-seeds/flat_dry_shade/1.jpg',
#  './pre-all/train-seeds/hanging_dry_shade',
#  './pre-all/train-seeds/hanging_dry_shade/IMG_20190911_011223.jpg',
#  './pre-all/train-seeds/hanging_dry_shade/IMG_20190911_212134.jpg',
#  './pre-all/train-seeds/hanging_dry_shade/IMG_20190911_211840.jpg',
#  './pre-all/train-seeds/hanging_dry_shade/IMG_20190910_235341.jpg',
#  './pre-all/train-seeds/hanging_dry_shade/IMG_20190910_235513.jpg',
#  './pre-all/train-seeds/hanging_dry_shade/1.jpeg',
#  './pre-all/train-seeds/hanging_dry_shade/IMG_20190911_212305.jpg',
#  './pre-all/train-seeds/hanging_dry_shade/IMG_20190909_234448.jpg',
#  './pre-all/train-seeds/hanging_dry_shade/IMG_20190911_212002.jpg',
#  './pre-all/train-seeds/hanging_dry_shade/IMG_20190910_235207.jpg',
#  './pre-all/train-seeds/wetcleaning_weak',
#  './pre-all/train-seeds/wetcleaning_weak/IMG_20190911_212041.jpg',
#  './pre-all/train-seeds/wetcleaning_weak/1.jpg',
#  './pre-all/train-seeds/drycleaning_F_weak',
#  './pre-all/train-seeds/drycleaning_F_weak/IMG_20190911_212426.jpg',
#  './pre-all/train-seeds/drycleaning_F_weak/IMG_0920.jpeg',
#  './pre-all/train-seeds/drycleaning_F_weak/IMG_20190911_211903.jpg',
#  './pre-all/train-seeds/drycleaning_F_weak/IMG_20190911_212329.jpg',
#  './pre-all/train-seeds/not_washable',
#  './pre-all/train-seeds/not_washable/images__7_.jpeg',
#  './pre-all/train-seeds/30_very_weak',
#  './pre-all/train-seeds/30_very_weak/2.png',
#  './pre-all/train-seeds/30_very_weak/1.jpg',
#  './pre-all/train-seeds/30_very_weak/3.png',
#  './pre-all/train-seeds/30_very_weak/IMG_20190911_212059.jpg',
#  './pre-all/train-seeds/30_very_weak/IMG_20190911_211925.jpg',
#  './pre-all/train-seeds/tumble_dry_upto80',
#  './pre-all/train-seeds/tumble_dry_upto80/senntaku_03_20170306.jpg',
#  './pre-all/train-seeds/ironing_upto110',
#  './pre-all/train-seeds/ironing_upto110/IMG_20190911_212413.jpg',
#  './pre-all/train-seeds/ironing_upto110/IMG_20190911_212015.jpg',
#  './pre-all/train-seeds/ironing_upto110/IMG_20190909_234503.jpg',
#  './pre-all/train-seeds/ironing_upto110/images.jpeg',
#  './pre-all/train-seeds/ironing_upto110/IMG_20190911_211853.jpg',
#  './pre-all/train-seeds/ironing_upto110/IMG_20190910_235225.jpg',
#  './pre-all/train-seeds/donot_wetcleaning',
#  './pre-all/train-seeds/donot_wetcleaning/1.jpeg',
#  './pre-all/train-seeds/95',
#  './pre-all/train-seeds/95/1.png']

# %%
del files[0]
files
# Out:
# ['./pre-all/train-seeds/ironing_upto150',
#  './pre-all/train-seeds/ironing_upto150/IMG_20190911_212318.jpg',
#  './pre-all/train-seeds/ironing_upto150/2.jpg',
#  './pre-all/train-seeds/ironing_upto150/IMG_20190911_212149.jpg',
#  './pre-all/train-seeds/ironing_upto150/ironing_upto150_2.jpg',
#  './pre-all/train-seeds/ironing_upto150/1.png',
#  './pre-all/train-seeds/ironing_upto150/ironing_upto150_3.jpg',
#  './pre-all/train-seeds/ironing_upto150/ironing_upto150_1.jpg',
#  './pre-all/train-seeds/ironing_upto150/3.jpeg',
#  './pre-all/train-seeds/bleachable_oxygen',
#  './pre-all/train-seeds/bleachable_oxygen/1.jpeg',
#  './pre-all/train-seeds/bleachable_oxygen/IMG_20190910_235440.jpg',
#  './pre-all/train-seeds/40_weak',
#  './pre-all/train-seeds/40_weak/4.jpeg',
#  './pre-all/train-seeds/40_weak/2.jpg',
#  './pre-all/train-seeds/40_weak/IMG_20190910_235118.jpg',
#  './pre-all/train-seeds/40_weak/3.jpg',
#  './pre-all/train-seeds/40_weak/40_weak_2.jpg',
#  './pre-all/train-seeds/40_weak/40_weak_1.jpg',
#  './pre-all/train-seeds/40_weak/1.png',
#  './pre-all/train-seeds/40_weak/40_weak_3.jpg',
#  './pre-all/train-seeds/40_weak/IMG_20190911_212228.jpg',
#  './pre-all/train-seeds/wetcleaning_ok',
#  './pre-all/train-seeds/wetcleaning_ok/1.jpg',
#  './pre-all/train-seeds/60_weak',
#  './pre-all/train-seeds/60_weak/1.png',
#  './pre-all/train-seeds/30_weak',
#  './pre-all/train-seeds/30_weak/2.png',
#  './pre-all/train-seeds/30_weak/1.jpg',
#  './pre-all/train-seeds/flat_dry_wet',
#  './pre-all/train-seeds/flat_dry_wet/1.jpg',
#  './pre-all/train-seeds/30',
#  './pre-all/train-seeds/30/2.jpg',
#  './pre-all/train-seeds/30/4.png',
#  './pre-all/train-seeds/30/1.jpg',
#  './pre-all/train-seeds/30/3.png',
#  './pre-all/train-seeds/50_weak',
#  './pre-all/train-seeds/50_weak/1.png',
#  './pre-all/train-seeds/60',
#  './pre-all/train-seeds/60/1.png',
#  './pre-all/train-seeds/drycleaning_F',
#  './pre-all/train-seeds/drycleaning_F/1.jpg',
#  './pre-all/train-seeds/hanging_dry_wetshade',
#  './pre-all/train-seeds/hanging_dry_wetshade/1.jpg',
#  './pre-all/train-seeds/donot_drycleaning',
#  './pre-all/train-seeds/donot_drycleaning/IMG_20190910_235237.jpg',
#  './pre-all/train-seeds/donot_drycleaning/IMG_20190909_234517.jpg',
#  './pre-all/train-seeds/donot_drycleaning/IMG_20190911_212159.jpg',
#  './pre-all/train-seeds/donot_drycleaning/IMG_20190911_212029.jpg',
#  './pre-all/train-seeds/donot_drycleaning/IMG_20190909_234107.jpg',
#  './pre-all/train-seeds/donot_drycleaning/IMG_0921.jpeg',
#  './pre-all/train-seeds/donot_drycleaning/IMG_20190910_235543.jpg',
#  './pre-all/train-seeds/donot_drycleaning/IMG_20190910_235411.jpg',
#  './pre-all/train-seeds/flat_dry_wetshade',
#  './pre-all/train-seeds/flat_dry_wetshade/1.jpg',
#  './pre-all/train-seeds/bleachable',
#  './pre-all/train-seeds/bleachable/jisl0001-ichiran.jpg',
#  './pre-all/train-seeds/donot_ironing',
#  './pre-all/train-seeds/donot_ironing/jisl0001-ichiran (1).jpg',
#  './pre-all/train-seeds/drycleaning_P_weak',
#  './pre-all/train-seeds/drycleaning_P_weak/IMG_20190911_011303.jpg',
#  './pre-all/train-seeds/drycleaning_P_weak/IMG_0917.jpeg',
#  './pre-all/train-seeds/40',
#  './pre-all/train-seeds/40/card_42748_001.jpg',
#  './pre-all/train-seeds/not_bleachable',
#  './pre-all/train-seeds/not_bleachable/IMG_20190911_212350.jpg',
#  './pre-all/train-seeds/not_bleachable/not_bleachable_1.jpg',
#  './pre-all/train-seeds/not_bleachable/IMG_20190911_211815.jpg',
#  './pre-all/train-seeds/not_bleachable/3.jpg',
#  './pre-all/train-seeds/not_bleachable/1.png',
#  './pre-all/train-seeds/not_bleachable/IMG_20190911_212112.jpg',
#  './pre-all/train-seeds/not_bleachable/4.jpg',
#  './pre-all/train-seeds/not_bleachable/IMG_20190911_211938.jpg',
#  './pre-all/train-seeds/not_bleachable/IMG_20190910_235141.jpg',
#  './pre-all/train-seeds/not_bleachable/not_bleachable_2.jpg',
#  './pre-all/train-seeds/not_bleachable/2.jpeg',
#  './pre-all/train-seeds/not_bleachable/IMG_20190911_212244.jpg',
#  './pre-all/train-seeds/hanging_dry',
#  './pre-all/train-seeds/hanging_dry/1.jpg',
#  './pre-all/train-seeds/70',
#  './pre-all/train-seeds/70/1.png',
#  './pre-all/train-seeds/weetcleaning_very_weak',
#  './pre-all/train-seeds/weetcleaning_very_weak/IMG_20190911_211913.jpg',
#  './pre-all/train-seeds/weetcleaning_very_weak/1.jpg',
#  './pre-all/train-seeds/weetcleaning_very_weak/IMG_20190911_212439.jpg',
#  './pre-all/train-seeds/weetcleaning_very_weak/IMG_20190911_212212.jpg',
#  './pre-all/train-seeds/40_very_weak',
#  './pre-all/train-seeds/40_very_weak/1.jpg',
#  './pre-all/train-seeds/tumble_dry_upto60',
#  './pre-all/train-seeds/tumble_dry_upto60/IMG_0923.jpeg',
#  './pre-all/train-seeds/flat_dry',
#  './pre-all/train-seeds/flat_dry/1.jpg',
#  './pre-all/train-seeds/drycleaning_P',
#  './pre-all/train-seeds/drycleaning_P/1.jpg',
#  './pre-all/train-seeds/50',
#  './pre-all/train-seeds/50/1.png',
#  './pre-all/train-seeds/ironing_upto200',
#  './pre-all/train-seeds/ironing_upto200/20160710_1748544.jpg',
#  './pre-all/train-seeds/hand-wash',
#  './pre-all/train-seeds/hand-wash/IMG_20190911_212341.jpg',
#  './pre-all/train-seeds/hand-wash/1.jpeg',
#  './pre-all/train-seeds/hand-wash/IMG_20190911_211805.jpg',
#  './pre-all/train-seeds/hanging_dry_wet',
#  './pre-all/train-seeds/hanging_dry_wet/1.jpg',
#  './pre-all/train-seeds/donot_tumble_dry',
#  './pre-all/train-seeds/donot_tumble_dry/IMG_20190911_211948.jpg',
#  './pre-all/train-seeds/donot_tumble_dry/IMG_20190911_211825.jpg',
#  './pre-all/train-seeds/donot_tumble_dry/IMG_20190911_212123.jpg',
#  './pre-all/train-seeds/donot_tumble_dry/3.jpg',
#  './pre-all/train-seeds/donot_tumble_dry/donot_tumble_dry_1.jpg',
#  './pre-all/train-seeds/donot_tumble_dry/1.png',
#  './pre-all/train-seeds/donot_tumble_dry/IMG_20190910_235155.jpg',
#  './pre-all/train-seeds/donot_tumble_dry/donot_tumble_dry_2.jpg',
#  './pre-all/train-seeds/donot_tumble_dry/donot_tumble_dry_3.jpg',
#  './pre-all/train-seeds/donot_tumble_dry/IMG_20190911_212403.jpg',
#  './pre-all/train-seeds/donot_tumble_dry/2.jpeg',
#  './pre-all/train-seeds/donot_tumble_dry/IMG_20190911_212256.jpg',
#  './pre-all/train-seeds/flat_dry_shade',
#  './pre-all/train-seeds/flat_dry_shade/1.jpg',
#  './pre-all/train-seeds/hanging_dry_shade',
#  './pre-all/train-seeds/hanging_dry_shade/IMG_20190911_011223.jpg',
#  './pre-all/train-seeds/hanging_dry_shade/IMG_20190911_212134.jpg',
#  './pre-all/train-seeds/hanging_dry_shade/IMG_20190911_211840.jpg',
#  './pre-all/train-seeds/hanging_dry_shade/IMG_20190910_235341.jpg',
#  './pre-all/train-seeds/hanging_dry_shade/IMG_20190910_235513.jpg',
#  './pre-all/train-seeds/hanging_dry_shade/1.jpeg',
#  './pre-all/train-seeds/hanging_dry_shade/IMG_20190911_212305.jpg',
#  './pre-all/train-seeds/hanging_dry_shade/IMG_20190909_234448.jpg',
#  './pre-all/train-seeds/hanging_dry_shade/IMG_20190911_212002.jpg',
#  './pre-all/train-seeds/hanging_dry_shade/IMG_20190910_235207.jpg',
#  './pre-all/train-seeds/wetcleaning_weak',
#  './pre-all/train-seeds/wetcleaning_weak/IMG_20190911_212041.jpg',
#  './pre-all/train-seeds/wetcleaning_weak/1.jpg',
#  './pre-all/train-seeds/drycleaning_F_weak',
#  './pre-all/train-seeds/drycleaning_F_weak/IMG_20190911_212426.jpg',
#  './pre-all/train-seeds/drycleaning_F_weak/IMG_0920.jpeg',
#  './pre-all/train-seeds/drycleaning_F_weak/IMG_20190911_211903.jpg',
#  './pre-all/train-seeds/drycleaning_F_weak/IMG_20190911_212329.jpg',
#  './pre-all/train-seeds/not_washable',
#  './pre-all/train-seeds/not_washable/images__7_.jpeg',
#  './pre-all/train-seeds/30_very_weak',
#  './pre-all/train-seeds/30_very_weak/2.png',
#  './pre-all/train-seeds/30_very_weak/1.jpg',
#  './pre-all/train-seeds/30_very_weak/3.png',
#  './pre-all/train-seeds/30_very_weak/IMG_20190911_212059.jpg',
#  './pre-all/train-seeds/30_very_weak/IMG_20190911_211925.jpg',
#  './pre-all/train-seeds/tumble_dry_upto80',
#  './pre-all/train-seeds/tumble_dry_upto80/senntaku_03_20170306.jpg',
#  './pre-all/train-seeds/ironing_upto110',
#  './pre-all/train-seeds/ironing_upto110/IMG_20190911_212413.jpg',
#  './pre-all/train-seeds/ironing_upto110/IMG_20190911_212015.jpg',
#  './pre-all/train-seeds/ironing_upto110/IMG_20190909_234503.jpg',
#  './pre-all/train-seeds/ironing_upto110/images.jpeg',
#  './pre-all/train-seeds/ironing_upto110/IMG_20190911_211853.jpg',
#  './pre-all/train-seeds/ironing_upto110/IMG_20190910_235225.jpg',
#  './pre-all/train-seeds/donot_wetcleaning',
#  './pre-all/train-seeds/donot_wetcleaning/1.jpeg',
#  './pre-all/train-seeds/95',
#  './pre-all/train-seeds/95/1.png']

# %%
end_list = ['.png', '.jpg', '.jpeg']
for i, f in enumerate(files):
    flag = 0
    for e in end_list:
        if e in f:
            flag = 1
            break
            
    if flag == 1:
        file_name = f
        print('file_name : ' + file_name)
        padding_images(dir_name, file_name, i)
        
    else:
        dir_name = f.split('/')[-1]
        print('dir_name : ' + dir_name)
# Out:
# dir_name : ironing_upto150
# file_name : ./pre-all/train-seeds/ironing_upto150/IMG_20190911_212318.jpg
# /home/ryuto/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   from ipykernel import kernelapp as app
# /home/ryuto/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:21: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
# file_name : ./pre-all/train-seeds/ironing_upto150/2.jpg
# file_name : ./pre-all/train-seeds/ironing_upto150/IMG_20190911_212149.jpg
# file_name : ./pre-all/train-seeds/ironing_upto150/ironing_upto150_2.jpg
# file_name : ./pre-all/train-seeds/ironing_upto150/1.png
# file_name : ./pre-all/train-seeds/ironing_upto150/ironing_upto150_3.jpg
# file_name : ./pre-all/train-seeds/ironing_upto150/ironing_upto150_1.jpg
# file_name : ./pre-all/train-seeds/ironing_upto150/3.jpeg
# dir_name : bleachable_oxygen
# file_name : ./pre-all/train-seeds/bleachable_oxygen/1.jpeg
# file_name : ./pre-all/train-seeds/bleachable_oxygen/IMG_20190910_235440.jpg
# dir_name : 40_weak
# file_name : ./pre-all/train-seeds/40_weak/4.jpeg
# file_name : ./pre-all/train-seeds/40_weak/2.jpg
# file_name : ./pre-all/train-seeds/40_weak/IMG_20190910_235118.jpg
# file_name : ./pre-all/train-seeds/40_weak/3.jpg
# file_name : ./pre-all/train-seeds/40_weak/40_weak_2.jpg
# file_name : ./pre-all/train-seeds/40_weak/40_weak_1.jpg
# file_name : ./pre-all/train-seeds/40_weak/1.png
# file_name : ./pre-all/train-seeds/40_weak/40_weak_3.jpg
# file_name : ./pre-all/train-seeds/40_weak/IMG_20190911_212228.jpg
# dir_name : wetcleaning_ok
# file_name : ./pre-all/train-seeds/wetcleaning_ok/1.jpg
# dir_name : 60_weak
# file_name : ./pre-all/train-seeds/60_weak/1.png
# dir_name : 30_weak
# file_name : ./pre-all/train-seeds/30_weak/2.png
# file_name : ./pre-all/train-seeds/30_weak/1.jpg
# dir_name : flat_dry_wet
# file_name : ./pre-all/train-seeds/flat_dry_wet/1.jpg
# dir_name : 30
# file_name : ./pre-all/train-seeds/30/2.jpg
# file_name : ./pre-all/train-seeds/30/4.png
# file_name : ./pre-all/train-seeds/30/1.jpg
# file_name : ./pre-all/train-seeds/30/3.png
# dir_name : 50_weak
# file_name : ./pre-all/train-seeds/50_weak/1.png
# dir_name : 60
# file_name : ./pre-all/train-seeds/60/1.png
# dir_name : drycleaning_F
# file_name : ./pre-all/train-seeds/drycleaning_F/1.jpg
# dir_name : hanging_dry_wetshade
# file_name : ./pre-all/train-seeds/hanging_dry_wetshade/1.jpg
# dir_name : donot_drycleaning
# file_name : ./pre-all/train-seeds/donot_drycleaning/IMG_20190910_235237.jpg
# file_name : ./pre-all/train-seeds/donot_drycleaning/IMG_20190909_234517.jpg
# file_name : ./pre-all/train-seeds/donot_drycleaning/IMG_20190911_212159.jpg
# file_name : ./pre-all/train-seeds/donot_drycleaning/IMG_20190911_212029.jpg
# file_name : ./pre-all/train-seeds/donot_drycleaning/IMG_20190909_234107.jpg
# file_name : ./pre-all/train-seeds/donot_drycleaning/IMG_0921.jpeg
# file_name : ./pre-all/train-seeds/donot_drycleaning/IMG_20190910_235543.jpg
# file_name : ./pre-all/train-seeds/donot_drycleaning/IMG_20190910_235411.jpg
# dir_name : flat_dry_wetshade
# file_name : ./pre-all/train-seeds/flat_dry_wetshade/1.jpg
# dir_name : bleachable
# file_name : ./pre-all/train-seeds/bleachable/jisl0001-ichiran.jpg
# dir_name : donot_ironing
# file_name : ./pre-all/train-seeds/donot_ironing/jisl0001-ichiran (1).jpg
# dir_name : drycleaning_P_weak
# file_name : ./pre-all/train-seeds/drycleaning_P_weak/IMG_20190911_011303.jpg
# file_name : ./pre-all/train-seeds/drycleaning_P_weak/IMG_0917.jpeg
# dir_name : 40
# file_name : ./pre-all/train-seeds/40/card_42748_001.jpg
# dir_name : not_bleachable
# file_name : ./pre-all/train-seeds/not_bleachable/IMG_20190911_212350.jpg
# file_name : ./pre-all/train-seeds/not_bleachable/not_bleachable_1.jpg
# file_name : ./pre-all/train-seeds/not_bleachable/IMG_20190911_211815.jpg
# file_name : ./pre-all/train-seeds/not_bleachable/3.jpg
# file_name : ./pre-all/train-seeds/not_bleachable/1.png
# file_name : ./pre-all/train-seeds/not_bleachable/IMG_20190911_212112.jpg
# file_name : ./pre-all/train-seeds/not_bleachable/4.jpg
# file_name : ./pre-all/train-seeds/not_bleachable/IMG_20190911_211938.jpg
# file_name : ./pre-all/train-seeds/not_bleachable/IMG_20190910_235141.jpg
# file_name : ./pre-all/train-seeds/not_bleachable/not_bleachable_2.jpg
# file_name : ./pre-all/train-seeds/not_bleachable/2.jpeg
# file_name : ./pre-all/train-seeds/not_bleachable/IMG_20190911_212244.jpg
# dir_name : hanging_dry
# file_name : ./pre-all/train-seeds/hanging_dry/1.jpg
# dir_name : 70
# file_name : ./pre-all/train-seeds/70/1.png
# dir_name : weetcleaning_very_weak
# file_name : ./pre-all/train-seeds/weetcleaning_very_weak/IMG_20190911_211913.jpg
# file_name : ./pre-all/train-seeds/weetcleaning_very_weak/1.jpg
# file_name : ./pre-all/train-seeds/weetcleaning_very_weak/IMG_20190911_212439.jpg
# file_name : ./pre-all/train-seeds/weetcleaning_very_weak/IMG_20190911_212212.jpg
# dir_name : 40_very_weak
# file_name : ./pre-all/train-seeds/40_very_weak/1.jpg
# dir_name : tumble_dry_upto60
# file_name : ./pre-all/train-seeds/tumble_dry_upto60/IMG_0923.jpeg
# dir_name : flat_dry
# file_name : ./pre-all/train-seeds/flat_dry/1.jpg
# dir_name : drycleaning_P
# file_name : ./pre-all/train-seeds/drycleaning_P/1.jpg
# dir_name : 50
# file_name : ./pre-all/train-seeds/50/1.png
# dir_name : ironing_upto200
# file_name : ./pre-all/train-seeds/ironing_upto200/20160710_1748544.jpg
# dir_name : hand-wash
# file_name : ./pre-all/train-seeds/hand-wash/IMG_20190911_212341.jpg
# file_name : ./pre-all/train-seeds/hand-wash/1.jpeg
# file_name : ./pre-all/train-seeds/hand-wash/IMG_20190911_211805.jpg
# dir_name : hanging_dry_wet
# file_name : ./pre-all/train-seeds/hanging_dry_wet/1.jpg
# dir_name : donot_tumble_dry
# file_name : ./pre-all/train-seeds/donot_tumble_dry/IMG_20190911_211948.jpg
# file_name : ./pre-all/train-seeds/donot_tumble_dry/IMG_20190911_211825.jpg
# file_name : ./pre-all/train-seeds/donot_tumble_dry/IMG_20190911_212123.jpg
# file_name : ./pre-all/train-seeds/donot_tumble_dry/3.jpg
# file_name : ./pre-all/train-seeds/donot_tumble_dry/donot_tumble_dry_1.jpg
# file_name : ./pre-all/train-seeds/donot_tumble_dry/1.png
# file_name : ./pre-all/train-seeds/donot_tumble_dry/IMG_20190910_235155.jpg
# file_name : ./pre-all/train-seeds/donot_tumble_dry/donot_tumble_dry_2.jpg
# file_name : ./pre-all/train-seeds/donot_tumble_dry/donot_tumble_dry_3.jpg
# file_name : ./pre-all/train-seeds/donot_tumble_dry/IMG_20190911_212403.jpg
# file_name : ./pre-all/train-seeds/donot_tumble_dry/2.jpeg
# file_name : ./pre-all/train-seeds/donot_tumble_dry/IMG_20190911_212256.jpg
# dir_name : flat_dry_shade
# file_name : ./pre-all/train-seeds/flat_dry_shade/1.jpg
# dir_name : hanging_dry_shade
# file_name : ./pre-all/train-seeds/hanging_dry_shade/IMG_20190911_011223.jpg
# file_name : ./pre-all/train-seeds/hanging_dry_shade/IMG_20190911_212134.jpg
# file_name : ./pre-all/train-seeds/hanging_dry_shade/IMG_20190911_211840.jpg
# file_name : ./pre-all/train-seeds/hanging_dry_shade/IMG_20190910_235341.jpg
# file_name : ./pre-all/train-seeds/hanging_dry_shade/IMG_20190910_235513.jpg
# file_name : ./pre-all/train-seeds/hanging_dry_shade/1.jpeg
# file_name : ./pre-all/train-seeds/hanging_dry_shade/IMG_20190911_212305.jpg
# file_name : ./pre-all/train-seeds/hanging_dry_shade/IMG_20190909_234448.jpg
# file_name : ./pre-all/train-seeds/hanging_dry_shade/IMG_20190911_212002.jpg
# file_name : ./pre-all/train-seeds/hanging_dry_shade/IMG_20190910_235207.jpg
# dir_name : wetcleaning_weak
# file_name : ./pre-all/train-seeds/wetcleaning_weak/IMG_20190911_212041.jpg
# file_name : ./pre-all/train-seeds/wetcleaning_weak/1.jpg
# dir_name : drycleaning_F_weak
# file_name : ./pre-all/train-seeds/drycleaning_F_weak/IMG_20190911_212426.jpg
# file_name : ./pre-all/train-seeds/drycleaning_F_weak/IMG_0920.jpeg
# file_name : ./pre-all/train-seeds/drycleaning_F_weak/IMG_20190911_211903.jpg
# file_name : ./pre-all/train-seeds/drycleaning_F_weak/IMG_20190911_212329.jpg
# dir_name : not_washable
# file_name : ./pre-all/train-seeds/not_washable/images__7_.jpeg
# dir_name : 30_very_weak
# file_name : ./pre-all/train-seeds/30_very_weak/2.png
# file_name : ./pre-all/train-seeds/30_very_weak/1.jpg
# file_name : ./pre-all/train-seeds/30_very_weak/3.png
# file_name : ./pre-all/train-seeds/30_very_weak/IMG_20190911_212059.jpg
# file_name : ./pre-all/train-seeds/30_very_weak/IMG_20190911_211925.jpg
# dir_name : tumble_dry_upto80
# file_name : ./pre-all/train-seeds/tumble_dry_upto80/senntaku_03_20170306.jpg
# dir_name : ironing_upto110
# file_name : ./pre-all/train-seeds/ironing_upto110/IMG_20190911_212413.jpg
# file_name : ./pre-all/train-seeds/ironing_upto110/IMG_20190911_212015.jpg
# file_name : ./pre-all/train-seeds/ironing_upto110/IMG_20190909_234503.jpg
# file_name : ./pre-all/train-seeds/ironing_upto110/images.jpeg
# file_name : ./pre-all/train-seeds/ironing_upto110/IMG_20190911_211853.jpg
# file_name : ./pre-all/train-seeds/ironing_upto110/IMG_20190910_235225.jpg
# dir_name : donot_wetcleaning
# file_name : ./pre-all/train-seeds/donot_wetcleaning/1.jpeg
# dir_name : 95
# file_name : ./pre-all/train-seeds/95/1.png

# %%
print("END")
# Out:
# END
